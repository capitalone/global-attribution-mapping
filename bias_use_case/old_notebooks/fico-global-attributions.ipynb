# %%
import sys
sys.path.insert(0, 'global-attribution-mapping/')
from gam import gam

# %%
local_attribution_path = 'deeplift_attributions-50-50-basline-1k-samples.csv'

# %%
g = gam.GAM(attributions_path = local_attribution_path, k=3)
g.generate()
# Out:
# Max Iterations:  1000
# Starting Iteration:  1

# %%
g.plot(num_features=5)

# %%
g.subpopulation_sizes
# Out:
# [450, 219, 331]
