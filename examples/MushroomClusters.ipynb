# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import pandas as pd

from gam import gam

# %%
local_attribution_path = 'data/mushroom-attributions-200-samples.csv'

# %%
g = gam.GAM(attributions_path = local_attribution_path, k=3)
g.generate()
# Out:
# Max Iterations:  1000
# Starting Iteration:  1
# Starting Iteration:  2

# %%
g.plot(num_features=7)

# %%
g.subpopulation_sizes
# Out:
# [79, 65, 56]

# %%
g.explanations
# Out:
# [[('cap-shape', 0.01825791031048172),
#   ('cap-surface', 0.008376866042681131),
#   ('cap-color', 0.042444218294873964),
#   ('bruises', 0.0024356302843576874),
#   ('odor', 0.2739508049117813),
#   ('gill-attachment', 0.0048033050503095715),
#   ('gill-spacing', 0.02403384912759166),
#   ('gill-size', 0.03504489168926918),
#   ('gill-color', 0.07370976099307944),
#   ('stalk-shape', 0.03642743459051172),
#   ('stalk-root', 0.05962940916617325),
#   ('stalk-surface-above-ring', 0.02867428599040516),
#   ('stalk-surface-below-ring', 0.01394072832702447),
#   ('stalk-color-above-ring', 0.05483203083131509),
#   ('stalk-color-below-ring', 0.05179942391181768),
#   ('veil-type', 0.0),
#   ('veil-color', 0.005573315795773394),
#   ('ring-number', 0.005027350722649562),
#   ('ring-type', 0.04809626577515543),
#   ('spore-print-color', 0.09844477389331338),
#   ('population', 0.07727135512413516),
#   ('habitat', 0.03722638916730007)],
#  [('cap-shape', 0.013075414821865465),
#   ('cap-surface', 0.006794783924350184),
#   ('cap-color', 0.03824665106049441),
#   ('bruises', 0.0036189685932889303),
#   ('odor', 0.2807971783299181),
#   ('gill-attachment', 0.0037594131503050653),
#   ('gill-spacing', 0.025386030904789733),
#   ('gill-size', 0.03565762760061357),
#   ('gill-color', 0.07019105044784028),
#   ('stalk-shape', 0.033223862172607505),
#   ('stalk-root', 0.05790576710123017),
#   ('stalk-surface-above-ring', 0.02884059593364032),
#   ('stalk-surface-below-ring', 0.019395474104668072),
#   ('stalk-color-above-ring', 0.050073884728126766),
#   ('stalk-color-below-ring', 0.05442225887962077),
#   ('veil-type', 0.0),
#   ('veil-color', 0.010303999927145662),
#   ('ring-number', 0.009301975051847046),
#   ('ring-type', 0.05194985874506608),
#   ('spore-print-color', 0.09610183039387274),
#   ('population', 0.07511315741724106),
#   ('habitat', 0.035840216711468094)],
#  [('cap-shape', 0.013806155969976006),
#   ('cap-surface', 0.0023589835827245646),
#   ('cap-color', 0.04355883555368676),
#   ('bruises', 0.005252210571921182),
#   ('odor', 0.26895759497402305),
#   ('gill-attachment', 0.0027145585292446574),
#   ('gill-spacing', 0.02852390673900576),
#   ('gill-size', 0.0357295999183282),
#   ('gill-color', 0.07559960428786205),
#   ('stalk-shape', 0.032317931619297476),
#   ('stalk-root', 0.06247702386583851),
#   ('stalk-surface-above-ring', 0.02873851609358443),
#   ('stalk-surface-below-ring', 0.015637154699266236),
#   ('stalk-color-above-ring', 0.05203794744696133),
#   ('stalk-color-below-ring', 0.05455570088209521),
#   ('veil-type', 0.0),
#   ('veil-color', 0.007068365652145767),
#   ('ring-number', 0.010637867575487719),
#   ('ring-type', 0.04325699562300275),
#   ('spore-print-color', 0.10018908689140461),
#   ('population', 0.07807431398394932),
#   ('habitat', 0.03850764554019452)]]
